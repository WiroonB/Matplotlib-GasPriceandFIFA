# %% [markdown]
# ### Load Nescessary Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### Real World Examples

# %% [markdown]
# #### Line Graph

# %%
gas = pd.read_csv(r"C:\Users\wiroo\Documents\Projects\Data Science\Matplotlib\gas_prices.csv")

gas
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# ...

# %%
plt.figure(figsize = (8,5)) # 8 by 5 ich

plt.title("Gas Prices over Time (in USD)")

plt.plot(gas.Year, gas.USA,"b.-", label = "USA")
plt.plot(gas.Year, gas.Canada,"r.-", label = "Canada")
plt.plot(gas.Year, gas["South Korea"],"g.-", label = "South Korea")

plt.xticks(gas.Year[::3].tolist()+[2011]) # every 3 years

plt.xlabel("Year")
plt.ylabel("US Dollars")

plt.legend()


plt.savefig("Gas Price over Time", dpi = 100)
plt.show()

# %%
# Another way to plot many values

our_countries = ["USA", "Canada", "South Korea"]
for country in gas:
    #if country != "Year":
    if country in our_countries:
        plt.plot(gas.Year, gas[country], marker = ".", label="{}".format(country))
        plt.legend()

# %% [markdown]
# ### Load FIFA Data

# %%
fifa = pd.read_csv(r"C:\Users\wiroo\Documents\Projects\Data Science\Matplotlib\fifa_data.csv")

fifa
# Out:
#        Unnamed: 0      ID                  Name  Age  \
# 0               0  158023              L. Messi   31
# 1               1   20801     Cristiano Ronaldo   33
# 2               2  190871             Neymar Jr   26
# 3               3  193080                De Gea   27
# 4               4  192985          K. De Bruyne   27
# 5               5  183277             E. Hazard   27
# 6               6  177003             L. Modrić   32
# 7               7  176580             L. Suárez   31
# 8               8  155862          Sergio Ramos   32
# 9               9  200389              J. Oblak   25
# 10             10  188545        R. Lewandowski   29
# 11             11  182521              T. Kroos   28
# 12             12  182493              D. Godín   32
# 13             13  168542           David Silva   32
# 14             14  215914              N. Kanté   27
# 15             15  211110             P. Dybala   24
# 16             16  202126               H. Kane   24
# ...

# %% [markdown]
# #### Histograms

# %%
bins = [40, 50, 60, 70, 80, 90, 100]

plt.hist(fifa.Overall, bins = bins)

plt.xticks(bins)
#plt.hist(fifa.Overall)

plt.ylabel("Number of Players")
plt.xlabel("Skill Level")
plt.title("Distribution of Player Skills in FIFA 2018")


plt.savefig("Distribution of Player Skills in FIFA 2018", dpi = 100)
plt.show()

# %% [markdown]
# #### Pie Charts

# %%
left = fifa.loc[fifa["Preferred Foot"] == "Left"].count()[0]
right = fifa.loc[fifa["Preferred Foot"] == "Right"].count()[0]

labels = ["Left", "Right"]
colors = ["#abcdef", "#aaabbb"]


plt.pie([left, right], labels = labels, colors = colors, autopct = "%.2f") 

plt.title("Foot Preference of FIFA Players")


plt.savefig("Foot Preference", dpi = 100)
plt.show()

# %%
fifa.Weight = [int(x.strip("lbs")) if type(x) == str else x for x in fifa.Weight]

plt.style.use('ggplot')


light = fifa.loc[fifa.Weight < 125].count()[0]
light_medium = fifa.loc[(fifa.Weight >= 125) & (fifa.Weight < 150)].count()[0]
medium = fifa.loc[(fifa.Weight >= 150) & (fifa.Weight < 175)].count()[0]
medium_heavy = fifa.loc[(fifa.Weight >= 175) & (fifa.Weight < 200)].count()[0]
heavy = fifa.loc[fifa.Weight >= 200].count()[0]

weights = [light, light_medium, medium, medium_heavy, heavy]
labels = ["Under 125", "125-150", "150-175", "175-200", "Over 200"]
explode = (.4, .2, 0, 0, .4)

plt.title("Weight Distribution of FIFA Players (in lbs.)")

plt.pie(weights, labels = labels, autopct = "%.2f %%", pctdistance = 0.8, explode = explode)


plt.savefig("Weight Distribution", dpi = 100)
plt.show()

# %% [markdown]
# #### Box and Whisker Charts

# %%
plt.style.use("default")

plt.figure(figsize = (5, 7))

barcelona = fifa.loc[fifa.Club == "FC Barcelona"]["Overall"]
madrid = fifa.loc[fifa.Club == "Real Madrid"]["Overall"]
revs = fifa.loc[fifa.Club == "New England Revolution"]["Overall"]

labels = ["FC Barcelona", "Real Madrid", "New England\nRevolution"]


boxes = plt.boxplot([barcelona, madrid, revs], labels = labels, patch_artist = True, medianprops = {"linewidth":2})

for box in boxes["boxes"]:
    box.set(color = "blue", linewidth = 2) #set edge color
    box.set(facecolor = "grey") #has to set patch_artist = true

plt.title("Professional Soccer Team Comparison")
plt.ylabel("FIFA Overall Rating")


plt.show
plt.savefig("Team Comparison", dpi = 100)
